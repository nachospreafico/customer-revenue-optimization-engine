# %% [markdown]
# # Data Understanding
#
# ## Objective
#
# The objective of this notebook is to develop a comprehensive understanding of the dataset before any data transformation, analysis, or modeling takes place.
#
# This phase focuses on identifying the available data sources, understanding the purpose and granularity of each table, evaluating overall data quality, and assessing whether the available information is sufficient to address the project's business objective.
#
# By the end of this notebook, the dataset should be fully understood from both a technical and business perspective, providing a solid foundation for SQL data modeling, exploratory data analysis, feature engineering, predictive modeling, and decision optimization.
#
# ## Business Problem
#
# ## Dataset Overview
#
# ## Data Sources
#
# ## Entity Overview
#
# ## Data Quality Assessment
#
# ## Initial Observations
#
# ## Questions to Investigate
#
# ## Next Steps
